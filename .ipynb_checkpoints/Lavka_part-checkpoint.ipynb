# %%
from goods import Moscl
from time import sleep
from Br import

# %%
browser = webdriver.Chrome()
print(Moscl)
# Out:
# ['Бекон сырокопчёный Дымов нарезка', 'Из Эквадора: Бананы 4 шт.', 'Брауни FitnesShock 15% протеина, без сахара, горячий шоколад', 'Бумага туалетная 2 слоя, 8 рулонов', 'Бумага туалетная Zewa Natural Comfort белая, 3 слоя, 6 рулонов', 'Вода минеральная Borjomi газированная, в стекле, 500 мл', 'Вода питьевая Святой Источник негазированная, 5 1 шт. по 1,5 л', 'Гуляш говядина, охлаждённый', 'Драже M&M’s с арахисом и молочным шоколадом', 'Картофель белый, мытый, 2 кг', 'Квас Очаковский фильтрованный, 2 л', 'Коин х Слой чизкейк, с малиной', 'Колбаса варёная Докторская в нарезке, категория А', 'Корм сухой Perfect Fit для стерилизованных кошек, с курицей', 'Котлета Creative Kitchen куриная, с картофельным пюре', 'Круассан с малиной', 'Манго жёлтое, 1 шт.', 'Молоко Простоквашино безлактозное ультрапастеризованное, 1,5%, 970 мл', 'Мороженое Трубочка, двухслойное, в глазури, 15%', 'Напиток Добрый Cola газированный, 1 л', 'Напиток Яблочный шорли натуральный, слабогазированный, 500 мл', 'Огурцы луховицкие', 'Салат Кухня на районе Оливье, с курицей', 'Салат Оливье с варёной колбасой']

# %%
url_lavka = 'https://lavka.yandex.ru'
url_ozon = 'https://www.ozon.ru/category/supermarket-25000/?__rr=1&miniapp=supermarket'
url_vkus = 'https://vkusvill.ru/?utm_source=admitad&utm_campaign=34f44854d746c3631a876c8ea4f49bec&utm_content=2125038&utm_medium=vakansii'

# %%
# t = pd.read_excel(r"C:\Users\nikit\Downloads\Тестовое задание.xlsx", sheet_name = ['Москва', 'Ростов-на-Дону'])
# Mos = t['Москва'].iloc[2:,0].to_list()
# Mos
# Moscl = []
# for i in Mos:
#     str = i.replace('+', ' ')
#     str = re.sub(r'\s+',' ', str.replace('Самокат ', ''))
#     if str[-2:] == ' г':
#         str = (re.search(r'[\S ]+(?=[,]\s\d+\s[г])', str))
#         str = str.group(0)
#     Moscl.append(str)

# %%
print(Moscl)
# Out:
# ['Бекон сырокопчёный Дымов нарезка', 'Из Эквадора: Бананы 4 шт.', 'Брауни FitnesShock 15% протеина, без сахара, горячий шоколад', 'Бумага туалетная 2 слоя, 8 рулонов', 'Бумага туалетная Zewa Natural Comfort белая, 3 слоя, 6 рулонов', 'Вода минеральная Borjomi газированная, в стекле, 500 мл', 'Вода питьевая Святой Источник негазированная, 5 1 шт. по 1,5 л', 'Гуляш говядина, охлаждённый', 'Драже M&M’s с арахисом и молочным шоколадом', 'Картофель белый, мытый, 2 кг', 'Квас Очаковский фильтрованный, 2 л', 'Коин х Слой чизкейк, с малиной', 'Колбаса варёная Докторская в нарезке, категория А', 'Корм сухой Perfect Fit для стерилизованных кошек, с курицей', 'Котлета Creative Kitchen куриная, с картофельным пюре', 'Круассан с малиной', 'Манго жёлтое, 1 шт.', 'Молоко Простоквашино безлактозное ультрапастеризованное, 1,5%, 970 мл', 'Мороженое Трубочка, двухслойное, в глазури, 15%', 'Напиток Добрый Cola газированный, 1 л', 'Напиток Яблочный шорли натуральный, слабогазированный, 500 мл', 'Огурцы луховицкие', 'Салат Кухня на районе Оливье, с курицей', 'Салат Оливье с варёной колбасой']

# %% [markdown]
# ## Перевод

# %%
def transliterate(name):
    if name.split(' ')[-1] == 'г':
        name = name[:-2]
   # Слоаврь с заменами
    slovar = {'а':'a','б':'b','в':'v','г':'g','д':'d','е':'e','ё':'yo',
      'ж':'zh','з':'z','и':'i','й':'j','к':'k','л':'l','м':'m','н':'n',
      'о':'o','п':'p','р':'r','с':'s','т':'t','у':'u','ф':'f','х':'h',
      'ц':'c','ч':'ch','ш':'sh','щ':'sch','ъ':'','ы':'y','ь':'','э':'e',
      'ю':'u','я':'ya', 'А':'A','Б':'B','В':'V','Г':'G','Д':'D','Е':'E','Ё':'YO',
      'Ж':'ZH','З':'Z','И':'I','Й':'I','К':'K','Л':'L','М':'M','Н':'N',
      'О':'O','П':'P','Р':'R','С':'S','Т':'T','У':'U','Ф':'F','Х':'H',
      'Ц':'C','Ч':'CH','Ш':'SH','Щ':'SCH','Ъ':'','Ы':'y','Ь':'','Э':'E',
      'Ю':'U','Я':'YA',',':'','?':'','~':'','!':'','@':'','#':'',
      '$':'','%':'','^':'','*':'','(':'',')':'','-':'','=':'',
      ':':'',';':'','<':'','>':'','\'':'','"':'','\\':'','/':'','№':'',
      '[':'',']':'','{':'','}':'','ґ':'','ї':'', 'є':'','Ґ':'g','Ї':'i',
      'Є':'e', '—':'', ' ':'_', '+':' '}
        
   # Циклически заменяем все буквы в строке
    for key in slovar:
        name = name.lower().replace(key, slovar[key])
    return name

# %% [markdown]
# ## Создание датафрейма

# %%
df = pd.DataFrame(columns = ['Лавка','Озон','Вкус','ЦЛ', 'ЦЛП','ЦО', 'ЦОП','ЦВ', 'ЦВП'], index = Mos)
df
# Out:
#                                                    Лавка Озон Вкус   ЦЛ  ЦЛП  \
# Бекон сырокопчёный Дымов нарезка, 150 г              NaN  NaN  NaN  NaN  NaN
# Из Эквадора: Бананы Самокат 4 шт.                    NaN  NaN  NaN  NaN  NaN
# Брауни FitnesShock 15% протеина, без сахара, го...   NaN  NaN  NaN  NaN  NaN
# Бумага туалетная Самокат 2 слоя, 8 рулонов           NaN  NaN  NaN  NaN  NaN
# Бумага туалетная Zewa Natural Comfort белая, 3 ...   NaN  NaN  NaN  NaN  NaN
# Вода минеральная Borjomi газированная, в стекле...   NaN  NaN  NaN  NaN  NaN
# Вода питьевая Святой Источник негазированная, 5...   NaN  NaN  NaN  NaN  NaN
# Гуляш Самокат говядина, охлаждённый, 380 г           NaN  NaN  NaN  NaN  NaN
# Драже M&M’s с арахисом и молочным шоколадом, 145 г   NaN  NaN  NaN  NaN  NaN
# Картофель белый, мытый, 2 кг                         NaN  NaN  NaN  NaN  NaN
# Квас Очаковский фильтрованный, 2 л                   NaN  NaN  NaN  NaN  NaN
# Салат Самокат Оливье с варёной колбасой, 250 г      NaN  NaN  NaN  NaN

# %% [markdown]
# ## Общие функции

# %% [markdown]
# ### Определение лучшего варианта из выдачи

# %%
def bestl(t, nm, k, price, full_price, name, weight = ''):
    nmt = transliterate(nm)
    c = 0
    best = ''
    for lt in t:
        print(lt)
        link = lt.find_element(By.TAG_NAME, 'a').get_attribute('href')
        price = lt.find_element(By.XPATH, price).text
        full_price = lt.find_element(By.XPATH, full_price).text
        name = lt.find_element(By.XPATH, name).text
        weight = lt.find_element(By.XPATH, weight).text
        if c == 0:
            print(name)
            price_of_best = price 
            full_price_of_best = full_price
            name_of_best = name 
            weight_best = weight
            c += 1
        try:
            nameinlink = link.split(r'/')[-1]
            if nmt.split().issubset(nameinlink.lower()) or nameinlink.split().lower().issubset(nmt):
                price_of_best = price 
                full_price_of_best = full_price
                name_of_best = name 
                weight_best = weight
                break
        except:
            break
    df.iloc[k, 0] = name + ', ' + weight
    df.iloc[k, 3] = price_of_best
    df.iloc[k, 4] = full_price_of_best

# %% [markdown]
# ### Перебор вариантов

# %%
def sup(searchbar, check, class_of_supply_el, weight = 0, m =''):
    for k in range(len(Moscl)):
        i = Moscl[k]
        searchbar.click()
        searchbar.send_keys(Keys.CONTROL + 'a' + Keys.DELETE)
        searchbar.send_keys(i)
        if m != 'l':
            searchbar.send_keys(Keys.ENTER)
        wait(browser, 15).until(EC.text_to_be_present_in_element((By.XPATH, check), i))
        t = browser.find_elements(By.CLASS_NAME, class_of_supply_el)
        bestl(t, i, k, price, full_price, name, weight)

# %% [markdown]
# ## Для Лавки

# %% [markdown]
# ### Установка геолокации

# %%
browser.get(url_lavka)
address = wait(browser, 10).until(EC.presence_of_element_located((By.XPATH,"/html/body/div/div[1]/header/div[2]/div[3]/button"))).click()
adrsstr = wait(browser, 10).until(EC.presence_of_element_located((By.XPATH,"/html/body/div[2]/div[3]/div/div/div/div[1]/div[2]/div[1]/div/input")))
adrsstr.send_keys(Keys.CONTROL + 'a' + Keys.DELETE)
adrsstr.send_keys('Москва, Запорожская улица, 5')
sleep(2)
adrsstr.send_keys(Keys.SPACE)
sleep(1)
wait(browser, 15).until(EC.presence_of_element_located((By.XPATH, '/html/body/div[2]/div[3]/div/div/div/div[1]/div[2]/div[1]/div/ul/li[1]'))).click()
but = wait(browser, 10).until(EC.presence_of_element_located((By.XPATH, '/html/body/div[2]/div[3]/div/div/div/div[1]/div[2]/div[2]/button')))
sleep(2)
but.click()
# for i in Mos:
#     print(i)
#     searchbar.send_keys(i)
#     break
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 browser.get(url_lavka)
#       2 address = wait(browser, 10).until(EC.presence_of_element_located((By.XPATH,"/html/body/div/div[1]/header/div[2]/div[3]/button"))).click()
#       3 adrsstr = wait(browser, 10).until(EC.presence_of_element_located((By.XPATH,"/html/body/div[2]/div[3]/div/div/div/div[1]/div[2]/div[1]/div/input")))
#
# File c:\Users\nikit\AppData\Local\Programs\Python\Python310\lib\site-packages\undetected_chromedriver\__init__.py:665, in Chrome.get(self, url)
#     662 def get(self, url):
#     663     # if self._get_cdc_props():
#     664     #     self._hook_remove_cdc_props()
# --> 665     return super().get(url)
#
# File c:\Users\nikit\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:356, in WebDriver.get(self, url)
#     354 def get(self, url: str) -> None:
#     355     """Loads a web page in the current browser session."""
# --> 356     self.execute(Command.GET, {"url": url})
#
# File c:\Users\nikit\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File c:\Users\nikit\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=126.0.6478.127)
# Stacktrace:
# 	GetHandleVerifier [0x0047C1C3+27395]
# 	(No symbol) [0x00413DC4]
# 	(No symbol) [0x00311B7F]
# 	(No symbol) [0x002EE483]
# 	(No symbol) [0x0037A06F]
# 	(No symbol) [0x0038C3D6]
# 	(No symbol) [0x00373736]
# 	(No symbol) [0x00347541]
# 	(No symbol) [0x003480BD]
# 	GetHandleVerifier [0x00733A93+2876371]
# 	GetHandleVerifier [0x00787F5D+3221661]
# 	GetHandleVerifier [0x004FD634+556916]
# 	GetHandleVerifier [0x0050474C+585868]
# 	(No symbol) [0x0041CE04]
# 	(No symbol) [0x00419818]
# 	(No symbol) [0x004199B7]
# 	(No symbol) [0x0040BF0E]
# 	BaseThreadInitThunk [0x762F7BA9+25]
# 	RtlInitializeExceptionChain [0x77CCC10B+107]
# 	RtlClearBits [0x77CCC08F+191]

# %% [markdown]
# ### Данные Лавки

# %%
price = 'div/div/div/div[1]/div[1]/div/div/div/span[4]/span[1]'
full_price = 'div/div/div/div[1]/div[1]/div/div/div/span[4]/span[2]/span[1]'
name = 'div/div/div/div[1]/div[1]/div/h3'
weight = 'div/div/div/div[1]/div[1]/span/span/span/span/span'
searchbar = wait(browser, 10).until(EC.presence_of_element_located((By.ID,"search-input-id")))
check = '/html/body/div/div[3]/div[1]/main/div/div/div/div[1]/div/div/h2'
class_of_supply_el = 'c8uba0o'
sup(searchbar, check, class_of_supply_el, weight, m = 'l')
# Out:
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.14746")>
# Бекон Дымов
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.14829")>
# Спелый банан
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.14870")>
# Бисквит проте­иновый FitnesShock брауни
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.14946")>
# Туалет­ная бумага Zewa Natural Comfort 3 слоя
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.15008")>
# Туалет­ная бумага Zewa Natural Comfort 3 слоя
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.15076")>
# Вода минераль­ная газиро­ванная Borjomi
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.15152")>
# Вода негази­рован­ная Святой источ­ник
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.15227")>
# Гуляш из говяди­ны Из Лавки
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.15293")>
# Драже M&M's арахис-шоколад
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.15369")>
# Карто­фель белый ранний
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.15401")>
# Квас Очаков­ский
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.15441")>
# Чизкейк малина Из Лавки
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.15481")>
# Колба­са Доктор­ская Клинский
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.15557")>
# Perfect Fit курица в соусе для стери­лизован­ных кошек
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.15619")>
# Грудка куриная с пюре Из Лавки
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.15689")>
# Круас­сан миндаль­ный с малиной
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.15752")>
# Манго жёлтое
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.15828")>
# Молоко безлак­тозное 1,5% Просто­кваши­но
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.15904")>
# Мороже­ное сливоч­ное Sunreme клубни­ка
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.15968")>
# Добрый Cola
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.16044")>
# Шорли яблоч­ный Из Лавки
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.16118")>
# Огурцы луховиц­кие
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.16182")>
# Салат оливье с колба­сой Из Лавки
# <undetected_chromedriver.webelement.WebElement (session="7ebe3a3cd49e34bc96a83bc18c840026", element="f.195AD25C9D7D48CD5A4FFD0B7D3B6535.d.EEA7165BB1834891835D4D3F178F3798.e.16240")>
# Салат оливье с колба­сой Из Лавки

# %%
df
# Out:
#                                                                                                 Лавка  \
# Бекон сырокопчёный Дымов нарезка, 150 г                                            Бекон Дымов, 150 г
# Из Эквадора: Бананы Самокат 4 шт.                                                 Спелый банан, 1 шт.
# Брауни FitnesShock 15% протеина, без сахара, го...      Бисквит проте­иновый FitnesShock брауни, 50 г
# Бумага туалетная Самокат 2 слоя, 8 рулонов          Туалет­ная бумага Zewa Natural Comfort 3 слоя,...
# Колбаса варёная Самокат Докторская в нарезке, к...  NaN  NaN  149 ₽  199 ₽
# Корм сухой Perfect Fit для стерилизованных коше...  NaN  NaN   23 ₽   39 ₽
# Котлета Creative Kitchen куриная, с картофельны...  NaN  NaN  209 ₽  349 ₽
# Круассан Самокат с малиной, 100 г                   NaN  NaN   89 ₽  149 ₽
# Манго жёлтое, 1 шт.                                 NaN  NaN  107 ₽  179 ₽
# Молоко Простоквашино безлактозное ультрапастери...  NaN  NaN  129 ₽  149 ₽
# Мороженое Самокат Трубочка, двухслойное, в глаз...  NaN  NaN   79 ₽  119 ₽
# Напиток Добрый Cola газированный, 1 л               NaN  NaN  105 ₽  125 ₽
# Напиток Самокат Яблочный шорли натуральный, сла...  NaN  NaN   83 ₽  139 ₽
# Огурцы луховицкие, 500 г                            NaN  NaN   59 ₽   99 ₽
# Салат Кухня на районе Оливье, с курицей, 180 г      NaN  NaN  215 ₽  359 ₽
# Салат Самокат Оливье с варёной колбасой, 250 г      NaN  NaN  215 ₽  359 ₽
#
#                                                      ЦО  ЦОП   ЦВ  ЦВП
# Бекон сырокопчёный Дымов нарезка, 150 г             NaN  NaN  NaN  NaN
# Из Эквадора: Бананы Самокат 4 шт.                   NaN  NaN  NaN  NaN
# Брауни FitnesShock 15% протеина, без сахара, го...  NaN  NaN  NaN  NaN
# Бумага туалетная Самокат 2 слоя, 8 рулонов          NaN  NaN  NaN  NaN
# Бумага туалетная Zewa Natural Comfort белая, 3 ...  NaN  NaN  NaN  NaN
# Вода минеральная Borjomi газированная, в стекле...  NaN  NaN  NaN  NaN
# Вода питьевая Святой Источник негазированная, 5...  NaN  NaN  NaN  NaN
# Гуляш Самокат говядина, охлаждённый, 380 г          NaN  NaN  NaN  NaN
# Драже M&M’s с арахисом и молочным шоколадом, 145 г  NaN  NaN  NaN  NaN
# Картофель белый, мытый, 2 кг                        NaN  NaN  NaN  NaN
# Квас Очаковский фильтрованный, 2 л                  NaN  NaN  NaN  NaN
# Коин Самокат х Слой чизкейк, с малиной, 110 г       NaN  NaN  NaN  NaN
# Колбаса варёная Самокат Докторская в нарезке, к...  NaN  NaN  NaN  NaN
# Корм сухой Perfect Fit для стерилизованных коше...  NaN  NaN  NaN  NaN
# Котлета Creative Kitchen куриная, с картофельны...  NaN  NaN  NaN  NaN
# Круассан Самокат с малиной, 100 г                   NaN  NaN  NaN  NaN
# Манго жёлтое, 1 шт.                                 NaN  NaN  NaN  NaN
# Молоко Простоквашино безлактозное ультрапастери...  NaN  NaN  NaN  NaN
# Мороженое Самокат Трубочка, двухслойное, в глаз...  NaN  NaN  NaN  NaN
# Напиток Добрый Cola газированный, 1 л               NaN  NaN  NaN  NaN
# Напиток Самокат Яблочный шорли натуральный, сла...  NaN  NaN  NaN  NaN
# Огурцы луховицкие, 500 г                            NaN  NaN  NaN  NaN
# Салат Кухня на районе Оливье, с курицей, 180 г      NaN  NaN  NaN  NaN
# Салат Самокат Оливье с варёной колбасой, 250 г      NaN  NaN  NaN  NaN

# %% [markdown]
# ## Для озон

# %% [markdown]
# ### Установка геолокации озон

# %%
browser.get(url_ozon)
sleep(1)
try:
    x_but = wait(browser, 10).until(EC.presence_of_element_located((By.XPATH, '/html/body/div[1]/div/div[1]/div[1]/div/div/div/div/div/div/div[1]/button')))
    sleep(0.1)
    x_but.click()
    adrstro = wait(browser, 10).until(EC.presence_of_element_located((By.XPATH, '/html/body/div[4]/div/div[2]/div/div/div/div/div/div/div[1]/div/div/div/div[1]/div/div/form/div/div/fieldset/div[1]/div/div/div/label/div[1]/div/textarea')))
    wait(browser, 15).until(EC.presence_of_element_located((By.XPATH, '/html/body/div[4]/div/div[2]/div/div/div/div/div/div/div[1]/div/div/div/div[1]/div/div/form/div/div/fieldset/div[1]/div/div/div/label/div[1]/div/div/div/button/span'))).click()
    adrstro.send_keys('Москва, Запорожская улица, 5')
    sleep(0.5)
    adrstro.send_keys(Keys.ENTER)
    sleep(1)
    wait(browser, 15).until(EC.presence_of_element_located((By.XPATH, '/html/body/div[5]/div/div/div/div'))).click()
    sleep(2)
    wait(browser, 10).until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[4]/div/div[2]/div/div/div/div/div/div/div[1]/div/div/div/div[2]/button'))).click()
    save_but = wait(browser, 10).until(EC.presence_of_element_located((By.XPATH, '/html/body/div[4]/div/div[2]/div/div/div/div/div/div/div[1]/div/div/div/div[2]/button')))
    sleep(0.1)
    save_but.click()
except:
    pass
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 browser.get(url_ozon)
#       2 sleep(1)
#       3 try:
#
# File c:\Users\nikit\AppData\Local\Programs\Python\Python310\lib\site-packages\undetected_chromedriver\__init__.py:665, in Chrome.get(self, url)
#     662 def get(self, url):
#     663     # if self._get_cdc_props():
#     664     #     self._hook_remove_cdc_props()
# --> 665     return super().get(url)
#
# File c:\Users\nikit\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:356, in WebDriver.get(self, url)
#     354 def get(self, url: str) -> None:
#     355     """Loads a web page in the current browser session."""
# --> 356     self.execute(Command.GET, {"url": url})
#
# File c:\Users\nikit\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File c:\Users\nikit\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=126.0.6478.127)
# Stacktrace:
# 	GetHandleVerifier [0x0047C1C3+27395]
# 	(No symbol) [0x00413DC4]
# 	(No symbol) [0x00311B7F]
# 	(No symbol) [0x002EE483]
# 	(No symbol) [0x0037A06F]
# 	(No symbol) [0x0038C3D6]
# 	(No symbol) [0x00373736]
# 	(No symbol) [0x00347541]
# 	(No symbol) [0x003480BD]
# 	GetHandleVerifier [0x00733A93+2876371]
# 	GetHandleVerifier [0x00787F5D+3221661]
# 	GetHandleVerifier [0x004FD634+556916]
# 	GetHandleVerifier [0x0050474C+585868]
# 	(No symbol) [0x0041CE04]
# 	(No symbol) [0x00419818]
# 	(No symbol) [0x004199B7]
# 	(No symbol) [0x0040BF0E]
# 	BaseThreadInitThunk [0x762F7BA9+25]
# 	RtlInitializeExceptionChain [0x77CCC10B+107]
# 	RtlClearBits [0x77CCC08F+191]

# %% [markdown]
# ### Сбор информации о товарах

# %%
searchstr = '/html/body/div[1]/div/div[1]/header/div[1]/div/div[2]/div/div/form/div/div[2]/input'
price = '#paginatorContent > div > div > div:nth-child(1) > div > div.jj7_23 > div.i7x_23.xi7_23.c306-a.c306-b3 > div > span.c306-a1.tsHeadline500Medium.c306-c0'
full_price = '#paginatorContent > div > div > div:nth-child(1) > div > div.jj7_23 > div.i7x_23.xi7_23.c306-a.c306-b3 > div > span.c306-a1.tsBodyControl400Small.c306-b0'
name = '#paginatorContent > div > div > div > div > div.jj7_23 > a > div > span'
check = '/html/body/div[1]/div/div[1]/header/div[1]/div/div[2]/div/div/form/div/div[2]/input'
class_sup = 'j8j_23'
sup(searchstr, check, class_sup)
# Out:
# Бекон сырокопчёный Дымов нарезка
# True
# [<undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.0A4E4C96C990275D7E25D721E8935CBE.e.37432")>]
# 1
# Дымов Бекон сырокопченый, нарезка, 200 г
# Из Эквадора: Бананы 4 шт.
# True
# [<undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.E914904FC15BC3DFA292979380004531.e.37681")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.E914904FC15BC3DFA292979380004531.e.37682")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.E914904FC15BC3DFA292979380004531.e.37683")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.E914904FC15BC3DFA292979380004531.e.37684")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.E914904FC15BC3DFA292979380004531.e.37685")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.E914904FC15BC3DFA292979380004531.e.37686")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.E914904FC15BC3DFA292979380004531.e.37687")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.E914904FC15BC3DFA292979380004531.e.37688")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.E914904FC15BC3DFA292979380004531.e.37689")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.E914904FC15BC3DFA292979380004531.e.37690")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.E914904FC15BC3DFA292979380004531.e.37691")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.E914904FC15BC3DFA292979380004531.e.37692")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.E914904FC15BC3DFA292979380004531.e.37693")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.E914904FC15BC3DFA292979380004531.e.37694")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.E914904FC15BC3DFA292979380004531.e.37695")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.E914904FC15BC3DFA292979380004531.e.37696")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.E914904FC15BC3DFA292979380004531.e.37697")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.E914904FC15BC3DFA292979380004531.e.37698")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.E914904FC15BC3DFA292979380004531.e.37699")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.E914904FC15BC3DFA292979380004531.e.37700")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.E914904FC15BC3DFA292979380004531.e.37701")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.E914904FC15BC3DFA2 ...
# 1
# Бананы, 0,4 - 1 кг
# Брауни FitnesShock 15% протеина, без сахара, горячий шоколад
# True
# [<undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.C8143CD047865A8775533F7FA1692223.e.37888")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.C8143CD047865A8775533F7FA1692223.e.37889")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.C8143CD047865A8775533F7FA1692223.e.37890")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.C8143CD047865A8775533F7FA1692223.e.37891")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.C8143CD047865A8775533F7FA1692223.e.37892")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.C8143CD047865A8775533F7FA1692223.e.37893")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.C8143CD047865A8775533F7FA1692223.e.37894")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.C8143CD047865A8775533F7FA1692223.e.37895")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.C8143CD047865A8775533F7FA1692223.e.37896")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.C8143CD047865A8775533F7FA1692223.e.37897")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.C8143CD047865A8775533F7FA1692223.e.37898")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.C8143CD047865A8775533F7FA1692223.e.37899")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.C8143CD047865A8775533F7FA1692223.e.37900")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.C8143CD047865A8775533F7FA1692223.e.37901")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.C8143CD047865A8775533F7FA1692223.e.37902")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.C8143CD047865A8775533F7FA1692223.e.37903")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.C8143CD047865A8775533F7FA1692223.e.37904")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.C8143CD047865A8775533F7FA1692223.e.37905")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.C8143CD047865A8775533F7FA1692223.e.37906")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.C8143CD047865A8775533F7FA1692223.e.37907")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.C8143CD047865A8775533F7FA1692223.e.37908")>, <undetected_chromedriver.webelement.WebElement (session="551e8ee2da8f46c16366b46980f15413", element="f.64D6965D8D734705F0D9409DD9867899.d.C8143CD047865A8775 ...
# 1
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[52], line 7
#       5 check = '/html/body/div[1]/div/div[1]/header/div[1]/div/div[2]/div/div/form/div/div[2]/input'
#       6 class_sup = 'j8j_23'
# ----> 7 sup(searchstr, check, class_sup)
#
# Cell In[36], line 14, in sup(searchstr, check, class_of_supply_el, weight, m)
#      12 print(wait(browser, 15).until(EC.text_to_be_present_in_element_value((By.XPATH, check), i)))
#      13 t = browser.find_elements(By.CLASS_NAME, class_of_supply_el)
# ---> 14 bestl(t, i, k, price, full_price, name, weight)
#
# Cell In[51], line 9, in bestl(t, nm, k, price, full_price, name, weight)
#       7 print(1)
#       8 link = lt.find_element(By.TAG_NAME, 'a').get_attribute('href')
# ----> 9 price = lt.find_element(By.CSS_SELECTOR, price).text
#      10 full_price = lt.find_element(By.CSS_SELECTOR, full_price).text
#      11 name = lt.find_element(By.CSS_SELECTOR, name).text
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webelement.py:417, in WebElement.find_element(self, by, value)
#     414     by = By.CSS_SELECTOR
#     415     value = f'[name="{value}"]'
# --> 417 return self._execute(Command.FIND_CHILD_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#paginatorContent > div > div > div:nth-child(1) > div > div.jj7_23 > div.i7x_23.xi7_23.c306-a.c306-b3 > div > span.c306-a1.tsHeadline500Medium.c306-c0"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0047C1C3+27395]
# 	(No symbol) [0x00413DC4]
# 	(No symbol) [0x00311B7F]
# 	(No symbol) [0x00352C65]
# 	(No symbol) [0x00352D3B]
# 	(No symbol) [0x00348D01]
# 	(No symbol) [0x003739E4]
# 	(No symbol) [0x00348C15]
# 	(No symbol) [0x00373C34]
# 	(No symbol) [0x0038CB24]
# 	(No symbol) [0x00373736]
# 	(No symbol) [0x00347541]
# 	(No symbol) [0x003480BD]
# 	GetHandleVerifier [0x00733A93+2876371]
# 	GetHandleVerifier [0x00787F5D+3221661]
# 	GetHandleVerifier [0x004FD634+556916]
# 	GetHandleVerifier [0x0050474C+585868]
# 	(No symbol) [0x0041CE04]
# 	(No symbol) [0x00419818]
# 	(No symbol) [0x004199B7]
# 	(No symbol) [0x0040BF0E]
# 	BaseThreadInitThunk [0x762F7BA9+25]
# 	RtlInitializeExceptionChain [0x77CCC10B+107]
# 	RtlClearBits [0x77CCC08F+191]
